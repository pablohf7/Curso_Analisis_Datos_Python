# %% [markdown]
# <a href="https://colab.research.google.com/github/pablohf7/Curso_Analisis_Datos_Python/blob/main/Dataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
lista_de_diccionarios =[
    {'nombre':'Ana','profesion':'guitarra','edad':34},
    {'nombre':'Luis','profesion':'fotografo','edad':27},
    {'nombre':'Maria','profesion':'profesora','edad':42},
    {'nombre':'Pedro','profesion':'Chef','edad':39},
    {'nombre':'Izabel','profesion':'Arquitecta','edad':29},
    {'nombre':'Sergio','profesion':'musico','edad':25},
    {'nombre':'Carla','profesion':'ingeniera','edad':31},
    {'nombre':'David','profesion':'estudiante','edad':20},
    {'nombre':'Lucia','profesion':'abogada','edad':36},
    {'nombre':'Jorge','profesion':'actor','edad':28}]

# %%
df= pd.DataFrame(lista_de_diccionarios)
df
# Out:
#    nombre   profesion  edad
# 0     Ana    guitarra    34
# 1    Luis   fotografo    27
# 2   Maria   profesora    42
# 3   Pedro        Chef    39
# 4  Izabel  Arquitecta    29
# 5  Sergio      musico    25
# 6   Carla   ingeniera    31
# 7   David  estudiante    20
# 8   Lucia     abogada    36
# 9   Jorge       actor    28

# %%
df2 = pd.read_csv('donut_lab_sales.csv')
df2
# Out:
#                     rosquilla  cantidad
# 0         Rosquilla de Filete        52
# 1          Rosquilla de Tacos        12
# 2            Rosquilla de Uva        62
# 3    Rosquilla de Champiñones        90
# 4          Rosquilla de Carne        22
# ..                        ...       ...
# 995        Rosquilla de Fresa        89
# 996    Rosquilla de Zanahoria        96
# 997         Rosquilla de Miel        44
# 998        Rosquilla de Queso        35
# 999       Rosquilla de Filete        64
#
# [1000 rows x 2 columns]

# %%
df3 = df2.groupby('rosquilla').sum('cantidad')
df3
# Out:
#                           cantidad
# rosquilla
# Rosquilla Vegana              2919
# Rosquilla de Bagel            3040
# Rosquilla de Banana           3026
# Rosquilla de Brócoli          2981
# Rosquilla de Carne            3436
# Rosquilla de Champiñones      2572
# Rosquilla de Filete           2413
# Rosquilla de Fresa            2930
# Rosquilla de Galleta          3386
# Rosquilla de Granja           3208
# Rosquilla de Hamburguesa      3806
# Rosquilla de Maíz             3580
# Rosquilla de Miel             3632
# Rosquilla de Queso            4299
# Rosquilla de Tacos            2880
# Rosquilla de Tocino           2581
# Rosquilla de Uva              3161
# Rosquilla de Zanahoria        2753
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['cantidad'].plot(kind='hist', bins=20, title='cantidad')
# ...
